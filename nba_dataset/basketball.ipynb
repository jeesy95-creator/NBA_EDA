# %%
import pandas as pd

df = pd.read_csv("/Users/jisoyun/Desktop/sparta_python/NBA/nba_dataset/games_details.csv", nrows=1000)
df1 =df.head(10)
df1.to_csv("/Users/jisoyun/Desktop/sparta_python/NBA/nba_dataset/games_details_shortver.csv")

# %%
rnk = pd.read_csv("/Users/jisoyun/Desktop/sparta_python/NBA/nba_dataset/ranking.csv")
rnk_short = rnk.head(20)
rnk_short.to_csv("/Users/jisoyun/Desktop/sparta_python/NBA/nba_dataset/ranking_stver.csv")
